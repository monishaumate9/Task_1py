# %% [markdown]
# # 1. Bold Text
# **This is bold text**

# %% [markdown]
# # 2. Horizontal Line
# --------------------------------------------------------
# ------------------------
# -------------------

# %% [markdown]
# # 3. italic text
# _italic text_

# %% [markdown]
# # 4. Bullet list
# * first item
# * second item
# * sub-item

# %% [markdown]
# # 5. Blockquotes
# > This is a quots

# %% [markdown]
# # 6. Tables
# |column1|column2 |
# |-------|--------|
# |item1  |item2   |

# %% [markdown]
# # 7. Emojis
# &#x1F600;

# %% [markdown]
# # 8. Maths expression
# $$ (energy)E = mc^2 $$

# %% [markdown]
# # 9. Line Breaks
# this is moon <br> this is sun

# %% [markdown]
# # 10. HTML tag
# <p style="colour:blue;">This is blue text</p>

# %% [markdown]
# # 11. Number list
# 1. first
# 2. second
# 3. third

# %% [markdown]
# # 12. strikethought
# ~~This is strikethought text~~

# %% [markdown]
# # 13. Image
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 14. Link
#
# [Google](https://www.google.com)

# %% [markdown]
# # 15. Heading
#
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6
